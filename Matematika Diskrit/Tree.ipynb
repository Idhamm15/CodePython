# %%
class Tree(object):
    "Generic tree node."
    def _init_(self, name='root', children=None):
        self.name = name
        self.children = []
        if children is not None:
            for child in children:
                self.add_child(child)
    def _repr_(self):
        return self.name
    def add_child(self, node):
        assert isinstance(node, Tree)
        self.children.append(node)
#    *
#   /|\
#  1 2 +
#     / \
#    3   4
t = Tree('*', [Tree('1'),
               Tree('2'),
               Tree('+', [Tree('3'),
                          Tree('4')])])


########################################

input =[17,46, 63, 2, 90, 1, 56, 4]
class node:
    def_nit_(self, key):
            self.key=key
            self.left=none
            self.right=none
class Pohon:
    def _init_(self):
        self.node = None
        self.height = -1
        self.balance = 0
############################################

ef insert(self, key):
        tree = self.node
        new_node = Node(key)
 
        if tree is None:
            self.node = new_node
            self.node.left = Pohon()
            self.node.right = Pohon()
 
        elif key < tree.key:
            self.node.left.insert(key)
 
        elif key > tree.key:
            self.node.right.insert(key)
